# %%
# !pip install --upgrade kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\rayshite\anaconda3\lib\site-packages (0.3.12)
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\rayshite\anaconda3\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\rayshite\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\rayshite\anaconda3\lib\site-packages (from kagglehub) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\rayshite\anaconda3\lib\site-packages (from kagglehub) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rayshite\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rayshite\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rayshite\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rayshite\anaconda3\lib\site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\rayshite\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
#   Attempting uninstall: kagglehub
#     Found existing installation: kagglehub 0.3.12
#     Uninstalling kagglehub-0.3.12:
#       Successfully uninstalled kagglehub-0.3.12
# Successfully installed kagglehub-0.3.13
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Импорт зависимостей

# %%
import os
import random
import shutil
from pathlib import Path

import kagglehub
from kagglehub import KaggleDatasetAdapter

# %% [markdown]
# ### Загрузка датасета

# %%
dataset_path = kagglehub.dataset_download('harishekar/chess-board-state-detection-dataset')
dataset_path
# Out:
# 'C:\\Users\\rayshite\\.cache\\kagglehub\\datasets\\harishekar\\chess-board-state-detection-dataset\\versions\\1'

# %% [markdown]
# ### Разделение данных на обучающюю, валидационную и тестовую выборки

# %%
SRC_DIR = Path(dataset_path) / "final_original_dataset"
DEST_DIR = Path("data")

# доли выборок
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

random.seed(42)

for class_dir in SRC_DIR.iterdir():
    if not class_dir.is_dir():
        continue

    class_name = class_dir.name 
    images = [p for p in class_dir.iterdir() if p.is_file()]
    random.shuffle(images)

    n_total = len(images)
    n_train = int(n_total * train_ratio)
    n_val = int(n_total * val_ratio)
    n_test = n_total - n_train - n_val  # остаток уходит в test

    splits = {
        "train": images[:n_train],
        "val":   images[n_train:n_train + n_val],
        "test":  images[n_train + n_val:],
    }

    for split_name, split_files in splits.items():
        target_dir = DEST_DIR / split_name / class_name
        target_dir.mkdir(parents=True, exist_ok=True)

        for src_path in split_files:
            dst_path = target_dir / src_path.name
            shutil.copy2(src_path, dst_path)

    print(f"{class_name}: total={n_total}, train={n_train}, val={n_val}, test={n_test}")
# Out:
# bB: total=100, train=70, val=15, test=15
# bK: total=100, train=70, val=15, test=15
# bN: total=100, train=70, val=15, test=15
# bP: total=100, train=70, val=15, test=15
# bQ: total=100, train=70, val=15, test=15
# bR: total=100, train=70, val=15, test=15
# empty: total=100, train=70, val=15, test=15
# wB: total=100, train=70, val=15, test=15
# wK: total=100, train=70, val=15, test=15
# wN: total=100, train=70, val=15, test=15
# wP: total=100, train=70, val=15, test=15
# wQ: total=100, train=70, val=15, test=15
# wR: total=100, train=70, val=15, test=15
